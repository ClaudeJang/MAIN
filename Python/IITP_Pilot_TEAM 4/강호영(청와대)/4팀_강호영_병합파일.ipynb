# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from IPython.display import Image
from time import sleep
import re
import pandas as pd
from datetime import datetime
from urllib.request import urlopen

# %% [markdown]
# # 페이지 오픈

# %%
search = input("검색어 입력: ")
driver_path = "./driver/chromedriver.exe"
driver = webdriver.Chrome(executable_path=driver_path)
url = "https://www1.president.go.kr/search"
driver.get(url)
driver.find_element_by_css_selector('#contents > div.search_PG_check > div > div.PG_calBtn > ul > li:nth-child(1) > ul > li > img').click()
driver.find_element_by_css_selector('#ui-datepicker-div > div > div > select.ui-datepicker-month').click()
driver.find_element_by_css_selector('#ui-datepicker-div > div > div > select.ui-datepicker-month > option:nth-child(1)').click()
driver.find_element_by_css_selector('#ui-datepicker-div > table > tbody > tr:nth-child(1) > td:nth-child(2) > a').click()
driver.find_element_by_css_selector('#contents > div.search_PG_check > div > div.PG_calBtn > ul > li:nth-child(3) > ul > li > img').click()
driver.find_element_by_css_selector('#ui-datepicker-div > div > div > select.ui-datepicker-month').click()
driver.find_element_by_css_selector('#ui-datepicker-div > div > div > select.ui-datepicker-month > option:nth-child(10)').click()
driver.find_element_by_css_selector('#ui-datepicker-div > table > tbody > tr:nth-child(5) > td:nth-child(4) > a').click()
driver.find_element_by_css_selector('#query').send_keys(search)
driver.find_element_by_css_selector('#login > li.search_PGbox_btn > input[type="image"]').click()
driver.find_element_by_css_selector('#contents > div.search_PG_contens > div > ul > li:nth-child(6) > a').click()
# Out:
# 검색어 입력: 민호

# %%
path = ('//*[@id="contents"]/div[2]/div/div[3]/div/div[2]/a[1]')
driver.find_element_by_xpath(path).click()
html = driver.page_source
soup = BeautifulSoup(html, "lxml")

# %%
type(soup.find_all("a", "on")[0].text)
# Out:
# str

# %% [markdown]
# # 크롤링 실시

# %%
soup2 = []

try:
    while True:
        a = 1
        b = 7*a

        for i in range(b):
            path = ('//*[@id="contents"]/div[2]/div/div[3]/div/div[2]/a[{}]'.format(i+1))
            driver.find_element_by_xpath(path).click()
            html = driver.page_source
            soup = BeautifulSoup(html, "lxml")
            soup2.append(soup)
            sleep(2)

        driver.find_element_by_xpath('//*[@id="contents"]/div[2]/div/div[3]/div/div[3]/a').click()
        a += 1
        sleep(5)
        
        if int(soup.find_all("a", "on")[0].text) != i:
            data3 = soup2
            print("크롤링 완료! data3을 불러주세요")
            
            break

        if a%50 == 0:
            sleep(60)
        else :
            pass
except:
    print("크롤링 실패!")
# Out:
# 크롤링 완료!

# %%
data3[0]
# Out:
# <!DOCTYPE html>
# <html class=" js csstransitions" lang="ko" style="height: auto;" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"/>
# <meta content="#082e59" name="theme-color"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="description"/>
# <meta content="청와대, 대통령비서실, 대통령, 한국, 대한민국, 대한민국 정부, president.go.kr, 靑瓦臺, 19대, 문재인" name="keywords"/>
# <meta content="청와대 (CHEONGWADAE)" name="author"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="website" property="og:type"/>
# <meta content="담요" property="og:title"/>
# <meta content="http://www.president.go.kr/" property="og:url"/>
# <meta content="담요" property="og:site_name"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." property="og:description"/>
# <meta content="http://president.go.kr/css/favicon_400x210.png" property="og:image"/>
# <meta content=" http://www.president.go.kr/" name="twitter:url"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="twitter:description"/>
# <meta content="http://president.go.kr/css/favicon_400x210.png" name="twitter:image"/>
# <title>담요</title>
# <link href="http://president.go.kr/css/favicon.ico" rel="shortcut icon"/>
# <link href="http://president.go.kr/css/favicon.png" rel="icon"/>
# <link href="http://president.go.kr/css/favicon.png" rel="apple-touch-icon"/>
# <link href="/css/init.css" rel="stylesheet"/>
# <link href="/css/common.css" rel="stylesheet"/>
# <link href="/css/layout.css?v=20170901" rel="stylesheet"/>
# <link href="/css/jquery.mCustomScrollbar.css" rel="stylesheet"/>
# <!-- <link rel="stylesheet" href="/css/flexslider.css"> -->
# <link href="/css/animate.min.css" rel="stylesheet"/>
# <link href="/css/board.css" rel="stylesheet"/>
# <link href="/css/header.css?ver=20171215" rel="stylesheet"/>
# <link href="/css/main.css" rel="stylesheet"/>
# <link href="/css/jquery-ui.min.css" rel="stylesheet"/>
# <link href="/css/sub_search.css?v=2" rel="stylesheet" type="text/css"/>
# <style type="text/css">
# small {font-size:0.6em;color:#808080;}
# </style>
# <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script src="/js/html5.js"></script>
# <script src="/js/jquery-1.11.0.min.js"></script>
# <script src="/js/jquery.form.min.js"></script>
# <script src="/js/navigation.js"></script>
# <script src="/js/jquery.validate.min.js"></script>
# <script src="/js/jquery.mCustomScrollbar.js"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-mousewheel/3.1.13/jquery.mousewheel.min.js"></script>
# <!-- <script src="/js/jquery.flexslider-min.js"></script> -->
# <script src="/js/jquery.appear.js"></script>
# <script src="/js/SmoothScroll.js"></script>
# <script src="/js/moment.min.js"></script>
# <script src="/js/handlebars-v4.0.10.js"></script>
# <script src="/js/jquery-ui.min.js"></script>
# <script src="/js/search.js?v=6" type="text/javascript"></script>
# <script>
# $(document).ready(function () {
#
#
#
# 	var webNavi = $('#webNavi').superfish({
# 	});
# });
# </script>
# </head>
# <body>
# <div id="accessibility">
# <strong class="blind">컨텐츠바로가기</strong>
# <ul>
# <li><a href="#cont_view"><strong>본문으로 바로가기</strong></a></li>
# <li><a href="#sitemap"><strong>하단메뉴 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="wrap">
# <div class="head_navi">
# <h1 style="transform: translate3d(0px, -40%, 0px);"><div class="sound_only">로고 배경이미지</div></h1>
# <div class="navigator_menu" style="position: fixed; top: 0px;">
# <ul class="menu sf-js-enabled sf-arrows" id="webNavi" style="touch-action: pan-y;">
# <li class="menu_list ml0 main_logo"><a href="/" style="padding: 15px; margin-top: -7px;" title="메인페이지로 이동"><img alt="청와대 로고" src="http://www.president.go.kr/cwdimg/main/logo.png" style="width:100%;"/></a></li>
# <li class="menu_list">
# <a class="sf-with-ul" href="/calendar">문재인 대통령</a>
# <ul class="menu_sub" style="display: none;">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙의 말과 글</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a class="sf-with-ul" href="/live-speeches">청와대 뉴스룸</a>
# <ul class="menu_sub" style="display: none;">
# <li><a href="/live-speeches">청와대 온에어</a></li>
# <li><a href="/c/briefings">청와대 브리핑</a></li>
# <li><a href="/c/oversea-journals">해외언론보도</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/TodayShot">오늘의 한 장</a></li>
# <li><a href="/econo_num">숫자로 읽는 우리 경제</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a class="sf-with-ul" href="/policies">정책자료</a>
# <ul class="menu_sub" style="display: none;">
# <li><a href="/policies">정책현안</a></li>
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2018" style="line-height:20px;">2018년 정부부처<br/>업무보고</a></li>
# <li><a href="/c/numerical-government">숫자로 보는 정책</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a class="sf-with-ul" href="/event" rel="noopener noreferrer" target="_blank" title="국민소통 광장 새창열림">국민소통 광장</a>
# <ul class="menu_sub" style="display: none;">
# <li><a href="/event" rel="noopener noreferrer" target="_blank" title="문재인 대통령 1주년 새창열림">문재인 대통령 1주년</a></li>
# <li><a href="/Amendment">국민 개헌안</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="/petitions">국민청원 및 제안</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="http://mybudget.go.kr" rel="noopener noreferrer" target="_blank" title="국민참여예산 새창열림">국민참여예산</a></li>
# <li><a href="https://www.hrdb.go.kr/OpenRecommend" rel="noopener noreferrer" target="_blank" title="인재추천 새창열림">인재추천</a></li>
# <li><a href="http://open.pss.go.kr" rel="noopener noreferrer" target="_blank" title="효자동사진관 새창열림">효자동사진관</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a class="sf-with-ul" href="/about/roi">청와대 알림</a>
# <ul class="menu_sub" style="display: none;">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="/recruit/recruitment.php">청와대 채용</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li><a href="/Verification" style="line-height:20px;">고위공직 예비후보자<br/>사전 질문서</a></li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="청와대 기록관 새창열림">청와대 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# </ul>
# </li>
# <li class="menu_list mr0">
# <a href="/tours/about">청와대 관람 신청</a>
# </li>
# <p class="main_search_icon"><button class="search_icon" id="trigger-overlay" type="button">검색창 열기</button></p>
# <div class="en_btn">
# <a href="http://english.president.go.kr" target="_blank" title="영문페이지로 새창열림">
# <span><img alt="" src="http://www.president.go.kr/cwdimg/main/language_icon.gif"/> English</span>
# </a>
# </div>
# </ul>
# <div class="overlay overlay-slidedown">
# <button class="overlay-close" type="button">닫기</button>
# <div class="full_search">
# <form action="/search" method="post">
# <fieldset>
# <ul class="full_search_btn">
# <li class="search_box">
# <label class="hide" for="loginid">검색창</label>
# <input id="loginid" name="query" placeholder="검색어를 입력해주세요." title="검색어입력" type="text" value=""/>
# </li>
# <li class="search_btn">
# <input type="submit" value="검색"/>
# </li>
# </ul>
# </fieldset>
# </form>
# </div>
# </div>
# <script src="/js/modernizr.custom.js"></script>
# <script src="/js/classie.js"></script>
# <script src="/js/search_btn.js"></script>
# </div>
# </div>
# <header class="on" id="header">
# <div class="navigator_menu" style="display: none; position: fixed; top: 0px;"></div>
# <div class="h_logo">
# <a href="/" title="메인페이지로 이동">
# <h1 class="blind">대한민국 청와대</h1>
# </a>
# </div>
# <hr/>
# <div class="h_search">
# <h2 class="blind">통합검색</h2>
# <div class="hs_btn">
# <button id="search_btn" type="button">
# <i><span class="sound_only">통합검색</span></i>
# <span class="blind">Search Btn</span>
# </button>
# </div>
# <div class="hs_wrap">
# <script>
# 				$(document).ready(function () {
# 					$('#form-search').submit(function () {
# 						var keyword = $(this).find('input[name="query"]').val();
# 						var regex = /^([a-zA-Z0-9가-힣 ]){2,}$/i;
# 						if (!regex.test(keyword)) {
# 							alert('검색어는 한글, 영문 숫자를 2글자 이상으로 입력해주세요.');
# 							return false;
# 						}
# 						return true;
# 					});
# 				});
# 			</script>
# <form action="/search" id="form-search">
# <fieldset>
# <legend>통합검색폼</legend>
# <div class="hs_group">
# <div class="hs_input">
# <label class="blind" for="hs_keyword">검색어</label>
# <input id="hs_keyword" name="query" placeholder="검색어를 입력해주세요." required="" type="text"/>
# </div>
# <button class="hs_ok" type="submit">검색</button>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <hr/>
# <div class="h_gnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="hg_btn">
# <h3>메뉴</h3>
# <button id="mainmenu_btn" type="button">
# <i><span class="sound_only">메인메뉴</span></i>
# <span class="blind">Menu Btn</span>
# </button>
# </div>
# <nav class="hg_wrap">
# <ul class="depth1">
# <li class="hg_president">
# <button type="button"><h3>문재인 대통령 <i><span class="sound_only">문재인 대통령</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/calendar">공개일정</a>
# </li>
# <li>
# <a href="/president-journey">걸어온길</a>
# </li>
# <li>
# <a href="/c/president-speeches">대통령의 말과 글</a>
# </li>
# <li>
# <a href="/c/first-lady-quotations">김정숙의 말과 글</a>
# </li>
# </ul>
# </li>
# <li class="hg_newsroom">
# <button type="button"><h3>청와대 뉴스룸 <i><span class="sound_only">청와대 뉴스룸</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/live-speeches">청와대 온에어</a>
# </li>
# <li>
# <a href="/c/briefings">청와대 브리핑</a>
# </li>
# <li>
# <a href="/c/oversea-journals">해외언론보도</a>
# </li>
# <li>
# <a href="/c/blue-house-stories">청와대 이야기</a>
# </li>
# <li>
# <a href="/TodayShot">오늘의 한 장</a>
# </li>
# <li>
# <a href="/econo_num">숫자로 읽는 우리 경제</a>
# </li>
# <li>
# <a href="/history">청와대 일기</a>
# </li>
# </ul>
# </li>
# <li class="hg_policy">
# <button type="button"><h3>정책자료 <i><span class="sound_only">정책자료</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/policies">정책현안</a>
# </li>
# <li>
# <a href="/government-projects">국정과제</a>
# </li>
# <li><a href="/GovReport2018" style="line-height:20px;">2018년 정부부처<br/>업무보고</a></li>
# <li>
# <a href="/c/numerical-government">숫자로 보는 정책</a>
# </li>
# </ul>
# </li>
# <li class="hg_community">
# <button type="button"><h3>국민소통 광장 <i><span class="sound_only">국민소통 광장</span></i></h3></button>
# <ul class="depth2">
# <li><a href="/event" rel="noopener noreferrer" target="_blank" title="문재인 대통령 1주년 새창열림">문재인 대통령 1주년</a></li>
# <li>
# <a href="/Amendment">국민 개헌안</a>
# </li>
# <li>
# <a href="/forums">토론방</a>
# </li>
# <li>
# <a href="/petitions">국민청원 및 제안</a>
# </li>
# <li>
# <a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a>
# </li>
# <li>
# <a href="http://mybudget.go.kr" rel="noopener noreferrer" target="_blank" title="국민참여예산 새창열림">국민참여예산</a>
# </li>
# <li>
# <a href="https://www.hrdb.go.kr/OpenRecommend" rel="noopener noreferrer" target="_blank" title="인재추천 새창열림">인재추천</a>
# </li>
# <li>
# <a href="http://open.pss.go.kr" rel="noopener noreferrer" target="_blank" title="효자동사진관 새창열림">효자동사진관</a>
# </li>
# </ul>
# </li>
# <li class="hg_cheongwadae">
# <button type="button"><h3>청와대 알림 <i><span class="sound_only">청와대 알림</span></i></h3></button>
# <ul class="depth2 hei325">
# <li>
# <a href="/about/roi">정보공개</a>
# </li>
# <li><a href="/recruit/recruitment.php">청와대 채용</a></li>
# <li>
# <a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a>
# </li>
# <li>
# <a href="/about/organization">청와대 조직도</a>
# </li>
# <li>
# <a href="/budgets">세입·세출예산 운용상황</a>
# </li>
# <li>
# <a href="/Verification" style="line-height:20px;">고위공직 예비후보자<br/>사전 질문서</a>
# </li>
# <li>
# <a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="청와대 기록관 새창열림">청와대 기록관</a>
# </li>
# <li>
# <a href="/about/location?where=desk">오시는 길</a>
# </li>
# </ul>
# </li>
# <li><button onclick="location.href='/tours/about';" type="button"><h3>청와대 관람 신청<i style="background-position-x:0;background-position-y:50%"><span class="sound_only">청와대 관람 신청</span></i></h3></button></li>
# <li><button onclick="location.href='http://english.president.go.kr';" type="button"><h3>English<i aria-hidden="true" class="fa fa-globe" style="background:none; font-size:38px"><span class="sound_only">English</span></i></h3></button></li>
# </ul>
# </nav>
# </div>
# </header>
# <div class="c_sub on" id="contents">
# <section class="searchPG_top" id="cont_view" style="background-image: url(/images/searchPage_bg.jpg);">
# <div class="search_PG_sc">
# <h3>
# <span class="PG_left_line"></span>
# 					통합검색
# 					<span class="PG_right_line"></span>
# </h3>
# <form action="/search" class="search_PG_area" id="searchForm" method="post">
# <input id="sortField" name="sortField" type="hidden" value="DATE"/>
# <input id="range" name="range" type="hidden" value="D"/>
# <input id="duration" name="duration" type="hidden" value="D"/>
# <input id="searchField" name="searchField" type="hidden" value="ALL"/>
# <input id="startCount" name="startCount" type="hidden" value="0"/>
# <input id="searchTarget" name="searchTarget" type="hidden" value="petitions"/>
# <input id="viewCount" name="viewCount" type="hidden" value="10"/>
# <input id="realSearchKeyword" name="realSearchKeyword" type="hidden" value="담요"/>
# <input id="reQuery" name="reQuery" type="hidden" value="2"/>
# <input id="startDate" name="startDate" type="hidden" value="2018/01/01"/>
# <input id="endDate" name="endDate" type="hidden" value="2018/10/31"/>
# <fieldset>
# <div id="select_box">
# <label for="color">국민청원 및 제안</label>
# <select id="color" title="검색항목 선택">
# <option value="ALL">통합검색</option>
# <option value="president">문재인대통령</option>
# <option value="news">청와대뉴스룸</option>
# <option value="policy">정책자료</option>
# <option value="agendas">토론방</option>
# <option selected="selected" value="petitions">국민청원 및 제안</option>
# </select>
# </div>
# <ul class="search_PGbox" id="login">
# <li class="search_PG_bar">
# <label class="hide" for="query">검색어</label>
# <input class="" id="query" name="query" title="검색어 입력" type="text" value="담요"/>
# </li>
# <li class="search_PGbox_btn">
# <input src="../images/searchPage_btn.jpg" title="검색하기" type="image"/>
# </li>
# </ul>
# </fieldset>
# </form>
# </div>
# </section>
# <div class="search_PG_check">
# <div class="search_PG_check_area">
# <div class="PG_check">
# <h4>검색대상</h4>
# <ul>
# <li><label for="chkAll"><input checked="" id="chkAll" name="searchChk" type="checkbox" value="ALL"/>전체</label></li>
# <li><label for="chkTitle"><input id="chkTitle" name="searchChk" type="checkbox" value="title"/>제목</label></li>
# <li><label for="chkContent"><input id="chkContent" name="searchChk" type="checkbox" value="content"/>내용</label></li>
# </ul>
# </div>
# <div class="PG_yearBtn">
# <h4>검색기간</h4>
# <ul>
# <li><a href="#" name="A">전체</a></li>
# <li><a href="#" name="W">최근 1주</a></li>
# <li><a href="#" name="Y">최근 1년</a></li>
# </ul>
# </div>
# <div class="PG_calBtn">
# <ul class="PG_cal">
# <li class="PG_cal_list">
# <ul class="PG_cal_box">
# <li class="PG_calBar">
# <label class="hide" for="start_Date">검색기간 시작 날짜 입력</label>
# <input class="hasDatepicker" id="start_Date" title="2018/01/01 형식으로 입력해주세요" type="text" value="2018/01/01"/><img alt="..." class="ui-datepicker-trigger" src="/images/searchPage_calBtn.png" style=" position: absolute; margin-left:-28px; top:6px; cursor:Pointer; border:0;" title="..."/>
# </li>
# <!--li class="PGcal_btn">
# 									<input type="image" src="../images/searchPage_calBtn.png" alt="달력"  title="달력버튼" />
# 								</li-->
# </ul>
# </li>
# <span>~</span>
# <li class="PG_cal_list">
# <ul class="PG_cal_box">
# <li class="PG_calBar">
# <label class="hide" for="end_Date">검색기간 끝 날짜 입력</label>
# <input class="hasDatepicker" id="end_Date" title="2018/01/01 형식으로 입력해주세요" type="text" value="2018/10/31"/><img alt="..." class="ui-datepicker-trigger" src="/images/searchPage_calBtn.png" style=" position: absolute; margin-left:-28px; top:6px; cursor:Pointer; border:0;" title="..."/>
# </li>
# <!--li class="PGcal_btn">
# 									<input type="image" src="../images/searchPage_calBtn.png" alt="달력"  title="달력버튼"/>
# 								</li-->
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="search_PG_contens">
# <div class="PG_contens">
# <div class="searchPG_title">
# 					검색어 <span class="searchPG_txt">"담요"</span> 에 대한 검색 결과입니다. <span class="searchPG_allNum">(70건)</span>
# </div>
# <ul class="work_btn">
# <li><a href="#" name="ALL">통합검색</a></li>
# <li><a href="#" name="president">문재인 대통령</a></li>
# <li><a href="#" name="news">청와대 뉴스룸</a></li>
# <li><a href="#" name="policy">정책자료</a></li>
# <li><a href="#" name="agendas">토론방</a></li>
# <li><a class="activePG" href="#" name="petitions" title="선택됨">국민청원 및 제안</a></li>
# <!--li><a href="">청와대 알림</a></li-->
# </ul>
# <div class="PG_contens_pd">
# <div class="searchPG_more">
# </div>
# <h3 class="searchPG_txt_icon">국민청원 및 제안(70)</h3>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/425617">
# <h2 style="margin-bottom:10px;">모든 학교의 화장, 복장 규제를 없애주세요</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-30</span>]</li>
# <li>[청원마감 : <span>2018-11-29</span>]</li>
# <li>[청원인원 : <span>11</span>]</li>
# </ul>
# <p>... 와이셔츠 단추로도 할 수 있을 뿐더러 오히려 히터를 트는 것이 더욱 잠이 옵니다 게다가 저희 반 몇몇 학생들은 반팔을 입기도 하고 덥다며 선풍기를 틀기도 합니다. 반면 몇몇 학생은 추워서 <font color="red">담요</font>를 갖고오고 목도리도 합니다. 이렇게 상반되는 상황에서 히터를 틀게되면 더 큰 불만과 문제가 생길 수 있습니다. 다음으로 저희는 체육복 등교가 허용되지 않는데요. 아마 많은 학교가 그럴 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/413931">
# <h2 style="margin-bottom:10px;">교복 폐지</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-21</span>]</li>
# <li>[청원마감 : <span>2018-11-20</span>]</li>
# <li>[청원인원 : <span>16</span>]</li>
# </ul>
# <p>... 요청합니다 그러면 이렇게들 말하시죠 기모스타킹 신고 다니라고 아니면 남자 교복 바지 사입으라고 기모스타킹이요? 겨울에 진짜 매일 입습니다 네 엄청 추워요 진짜 입고도 항상 다리 떨고 다녀서 <font color="red">담요</font> 없이는 생활이 안돼요 남자바지 사 입으라고요? 돈이 하늘에서 굴러떨어집니까 안 그래도 비싼데 그거 따로 살 돈이 어딨어요 그리고 남자 교복 바지도 얇아요 이래놓고 쳬육복 입고 못 돌아다니게 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/411058">
# <h2 style="margin-bottom:10px;">비효율성인 교복을 없애주세요.</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-19</span>]</li>
# <li>[청원마감 : <span>2018-11-18</span>]</li>
# <li>[청원인원 : <span>26</span>]</li>
# </ul>
# <p>... 합니다. 하지만 스타킹은 활동량이 많은 청소년에게는 매우 불편하고 스타킹의 재질 자체가 매우 찢어지기 쉽고 찢어지면 계속해서 사야합니다. 하지만 그러한 스타킹의 보온성의 부족 으로 인해 <font color="red">담요</font>를 들고 다니면 학교에서는 또다시 제의를 하고 꾸중을 듣고 벌점을 맞기도 합니다. 다리가 추워서 동복 체육복을 입으면 체육시간도 아닌데 왜 입냐며 한소리씩 듣거나 갈아입으라고 합니다. 여섯번 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/406214">
# <h2 style="margin-bottom:10px;">안녕하세요. 노숙자 분이 부모님이라고 생각해주시고 봐주세요.</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-14</span>]</li>
# <li>[청원마감 : <span>2018-11-13</span>]</li>
# <li>[청원인원 : <span>6</span>]</li>
# </ul>
# <p>... 보태서 노숙자 분께 사용하겠습니다. 예전에 나온 자원단체가 돈을 빼돌리는 그런 사람이 아닌 저는 1푼도 제가 사용안하고 인증을 하며 밑에 페이스북 페이지에 글을 올려서 노숙자분들께 식사나 <font color="red">담요</font>를 기부해드리는 캠페인을 하겠습니다. 광주광역시에 사시는 분들 관심있으시면 페이스북 밑에 주소로 오셔서 메세지 보내주시면 같이 다니겠습니다. 좋아요 누르시면 팔로윙 되니까요. 꾸준히 정기적으로 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/405978">
# <h2 style="margin-bottom:10px;">진짜 너무한 거 아닌가요? 학생도 선생님과 똑같이 추위를 느낍니다.</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-13</span>]</li>
# <li>[청원마감 : <span>2018-11-12</span>]</li>
# <li>[청원인원 : <span>14</span>]</li>
# </ul>
# <p>저는 인천의 한 중학교 3학년입니다. 기온이 점점 내려가고 있고, 아침에는 학생들이 오들오들 떨며 등교를 하고 학교 내에서도 추운기온 탓에 <font color="red">담요</font>나 옷을 싸매고 있는 학생들이 많습니다. 저희 학교의 규정은 '마이위에 입는 사복'은 허용하는 것이였는데, 바로 어제 학교에서 공지하길 다음주 월요일부터 당장 마이위에 입는 사복또한 압수해가고 체크하겠다 라고 말합니다. ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/403890">
# <h2 style="margin-bottom:10px;">평범한 사람의 판단에 맡깁니다.</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-11</span>]</li>
# <li>[청원마감 : <span>2018-11-10</span>]</li>
# <li>[청원인원 : <span>2</span>]</li>
# </ul>
# <p>... 갖추지 못한 증거로서 이를 근거로 한 판단은 채증법칙을 위반한 것으로 타당하지 않습니다. (3) 실제로 확인서 기재내용을 보면 이미 게임 벌칙으로 술을 많이 먹고, 술과 물 등 음료가 묻은 <font color="red">담요</font>를 잘못 밟아 넘어져 상해를 입은 원고에 대하여 “저는 공00 학우가 혹시나 술을 많이 먹은 상태로 온 것은 아닌지 걱정”했다고 하면서도 “선배의 부축하에 멀쩡히 들어”왔다거나 “공00 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/398626">
# <h2 style="margin-bottom:10px;">서울 교육청 두발 자율화 반대, 교복 개정 및 보안 찬성</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-05</span>]</li>
# <li>[청원마감 : <span>2018-11-04</span>]</li>
# <li>[청원인원 : <span>20</span>]</li>
# </ul>
# <p>... 자율화가 실행된다면 학생들을, 학교를 더 망치는 일 밖에 되지 않습니다. 차라리 교복 개정 및 보안을 해주십시오. 저희는 얇은 긴팔 교복으로 이 시기를 견디고 있습니다. 사복 외투나 <font color="red">담요</font>는 학교에서 교칙 위반이 되고, 만약 보일 경우 일주일간 학교에서 보관을 하게됩니다. 저희는 불편하고 질도 안 좋은 교복을 입으며 불편하게 공부를 합니다. 반면 선생님들은 따뜻하게 지내시고 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/396929">
# <h2 style="margin-bottom:10px;">대구  모든중학교에  사복입을수 있게 해주세료</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-10-03</span>]</li>
# <li>[청원마감 : <span>2018-11-02</span>]</li>
# <li>[청원인원 : <span>0</span>]</li>
# </ul>
# <p>중학교 고등학교에서 교복을 입습니다 근데 겨울엔 교복 치마를 입으면 너무 춥습니다 롱패딩을 입어도, <font color="red">담요</font>를 써도 춥습니다. 여름에는 치마가 너무길어 덥습니다,, 그리고 사복을 입으면 여름에는 반바지,반팔티를 입어서 시원하고,겨울에는 긴팔,긴바지를 입어서 춥지 않습니다 그래서 중학교,고등학교때 교복을 입어야되기는 하지만 여름,겨울에 불편합니다 체육복을 갈아입을때도 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/391268">
# <h2 style="margin-bottom:10px;">문재인 대통령께 표창 받은 병원에서 겪은 이상한 일들을 알립니다.</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-09-27</span>]</li>
# <li>[청원마감 : <span>2018-10-27</span>]</li>
# <li>[청원인원 : <span>9</span>]</li>
# </ul>
# <p>... 손이 제 물건에 닿기만 해도 결벽증이 발동해서 그 물건들을 다 내다 버릴 상태가 되었습니다. 그래서 제가 박○석 보호사께 제 심정이 그렇다고 말씀드렸고 제가 퇴원할때 비닐봉지에 베개와 <font color="red">담요</font>가 들어있는 짐 외에는 손을 대지 않아주셔서 그것 단 한가지를 아주 감사하게 생각하고 있습니다. 6) 09월 10일 저녁식사 시간 모든 환자와 직원들에게 배식이 끝났고, 남은 반찬이 제법 있었습니다. ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# <div class="PG_contens_pd_list">
# <a class="pd_list_link" href="/petitions/391048">
# <h2 style="margin-bottom:10px;">아기고양이 살려주세요</h2>
# <ul class="PG_peti_list">
# <li>[청원시작 : <span>2018-09-27</span>]</li>
# <li>[청원마감 : <span>2018-10-27</span>]</li>
# <li>[청원인원 : <span>15</span>]</li>
# </ul>
# <p>... 벌벌떨면서 다리를 움직이지못하는 아기 길냥이를만났습니다 빌라 현관앞에서 갑자기 사람이 나타나니 무서웠는지 앞다리만 들고 뒷다리 질질끌면서 도망가는거 더위험해질까봐 일단 박스구해서 넣어주고 <font color="red">담요</font>도 덮어주었습니다 굶었을까봐 참치 물로씻어서 주고 물도 주었지만 계속 울기만하고 먹지 않아서 너무걱정되어 일단 급한마음에 24시 병원을 찾아서 데리고 갔습니다 거기서 하시는말씀이 엑스레이상으론 ...</p>
# </a>
# <ul>
# <li>HOME &gt; 국민소통광장 &gt; 국민청원 및 제안</li>
# </ul>
# </div>
# </div>
# <div class="paging">
# <div class="p_wrap">
# <div class="p_btn prev"><a href="#">Prev</a></div><div class="p_btn"><a class="on" href="#none"><strong>1</strong></a><a onclick="goPage(10)">2</a><a onclick="goPage(20)">3</a><a onclick="goPage(30)">4</a><a onclick="goPage(40)">5</a><a onclick="goPage(50)">6</a><a onclick="goPage(60)">7</a></div><div class="p_btn next"><a href="#">Next</a></div> </div>
# </div><!-- paging 끝 -->
# </div><!-- PG_contens 끝 -->
# </div><!-- search_PG_contens 끝 -->
# </div>
# <div id="sitemap">
# <button class="s_btn">사이트맵 <span class="blind">버튼</span></button>
# <div class="wrap">
# <ul class="depth1">
# <li>
# <h3>문재인 대통령
# 					<a class="blind" href="/calendar">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙의 말과 글</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 뉴스룸<a class="blind" href="/live-speeches">바로가기</a></h3>
# <ul class="depth2">
# <li><a href="/live-speeches">청와대 온에어</a></li>
# <li><a href="/c/briefings">청와대 브리핑</a></li>
# <li><a href="/c/oversea-journals">해외언론보도</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/TodayShot">오늘의 한 장</a></li>
# <li><a href="/econo_num">숫자로 읽는 우리 경제</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li>
# <h3>정책자료<a class="blind" href="/policies">바로가기</a></h3>
# <ul class="depth2">
# <li><a href="/policies">정책현안</a></li>
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2018">2018년 정부부처 업무보고</a></li>
# <li><a href="/c/numerical-government">숫자로 보는 정책</a></li>
# </ul>
# </li>
# <li>
# <h3>국민소통 광장<a class="blind" href="/event" rel="noopener noreferrer" target="_blank" title="국민소통 광장 새창열림">바로가기</a></h3>
# <ul class="depth2">
# <li><a href="/event" rel="noopener noreferrer" target="_blank" title="문재인 대통령 1주년 새창열림">문재인 대통령 1주년</a></li>
# <li><a href="/Amendment">국민 개헌안</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="/petitions">국민청원 및 제안</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="http://mybudget.go.kr" rel="noopener noreferrer" target="_blank" title="국민참여예산 새창열림">국민참여예산</a></li>
# <li><a href="https://www.hrdb.go.kr/OpenRecommend" rel="noopener noreferrer" target="_blank" title="인재추천 새창열림">인재추천</a></li>
# <li><a href="http://open.pss.go.kr" rel="noopener noreferrer" target="_blank" title="효자동사진관 새창열림">효자동사진관</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 알림<a class="blind" href="/about/roi">바로가기</a></h3>
# <ul class="depth2">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="/recruit/recruitment.php">청와대 채용</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li>
# <a href="/Verification">고위공직 예비후보자<br/>사전 질문서</a>
# </li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="청와대 기록관 새창열림">청와대 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# <li><a href="/tours/about" style="font-size:15px; color:#fff; font-weight:bold; margin-top:12px; text-decoration:none;">청와대 관람신청</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div> <hr/>
# <!-- footer -->
# <style>
# #footer .f_menu .fm_tip{
# 	line-height:20px;
# 	margin-bottom:6px;
# }
#
# @media screen and (max-width:768px){
# 	.footer_mark{display: none;}
# }
# </style>
# <footer id="footer">
# <div class="wrap">
# <div class="f_group">
# <div class="f_logo">
# <h2 class="blind">대한민국 청와대</h2>
# </div>
# <div class="f_sns">
# <h2 class="blind">SNS 바로가기</h2>
# <ul>
# <li><a href="https://www.facebook.com/TheBlueHouseKR" target="_blank"><i class="fs_icon facebook"><span class="sound_only">페이스북 바로가기</span></i><span class="blind">Facebook</span></a></li>
# <li>
# <a href="https://blog.naver.com/thebluehousekr" target="_blank"><i class="fs_icon blog"><span class="sound_only">블로그 바로가기</span></i><span class="blind">blog</span></a>
# </li>
# <li><a href="https://twitter.com/TheBlueHouseKR" target="_blank"><i class="fs_icon twitter"><span class="sound_only">트위터 바로가기</span></i><span class="blind">Twitter</span></a></li>
# <li><a href="https://www.instagram.com/thebluehouse_kr/" target="_blank"><i class="fs_icon instagram"><span class="sound_only">인스타그램 바로가기</span></i><span class="blind">Instagram</span></a></li>
# <li><a href="https://www.youtube.com/TheBlueHouseKR" target="_blank"><i class="fs_icon youtube"><span class="sound_only">유튜브 바로가기</span></i><span class="blind">Youtube</span></a></li>
# </ul>
# </div>
# </div>
# <div class="f_wrap">
# <div class="f_info">
# <h2>CONTACT INFO</h2>
# <ul>
# <li><i class="fi_icon call"><span class="sound_only">대표전화</span></i><p><a href="tel:02-730-5800">(+82) 02-730-5800</a></p></li>
# <li><i class="fi_icon email"><span class="sound_only">담당자 메일</span></i><p> 담당자 메일 : <a href="mailto:webmaster@president.go.kr">메일보내기</a></p></li>
# <li><i class="fi_icon address"><span class="sound_only">청와대 주소</span></i><p>03048 서울특별시 종로구 청와대로 1 대통령 비서실</p></li>
# </ul>
# </div>
# <div class="f_menu">
# <div class="fm_wrap">
# <ul>
# <li><a href="http://www1.president.go.kr/about/privacy">개인정보처리방침</a></li>
# <li><a href="http://www1.president.go.kr/about/copyright">저작권 정책</a></li>
# <li><a href="http://www1.president.go.kr/sitemap">사이트맵</a></li>
# <li><a href="http://www1.president.go.kr/about/location">오시는 길</a></li>
# </ul>
# <ul></ul>
# </div>
# <div class="fm_tip">
# 						해당 메일은 기능 장애 등 홈페이지 관련 문의만 접수합니다.<br/>
# 						청와대 및 정부에 대한 민원·제안 및 공익신고·고발 등은
# 						국민신문고(<a href="http://www.epeople.go.kr/" target="_blank" title="새창 열림">www.epeople.go.kr</a>)로
# 						접수해주시길 부탁드립니다.
# 					</div>
# <ul class="footer_mark">
# <li><img alt="wa품질인증마크" src="http://www.president.go.kr/cwdimg/main/wa_mark.png"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="f_copyright">
# 			© Office of the President. All rights reserved.
# 		</div>
# </footer> <!-- footer -->
# </div>
# <script>
# </script>
# <script src="/js/common.js"></script>
# <script type="text/javascript">
# &lt;!--
#
#
# $(function() {
#   var select = $('select#color');
#
#   select.change(function() {
#     var select_name = $(this).children('option:selected').text();
#     $(this).siblings('label').text(select_name);
#   });
# });
#
#
#
# //--&gt;
# </script>
# <!-- AceCounter Log Gathering Script -->
# <script language="javascript">
# 	if(typeof _GUL == 'undefined'){
# 	var _GUL = 'count.president.go.kr';var _GPT='80';var _SGPT='443';var _AIMG = new Image(); var _bn=navigator.appName; var _PR = location.protocol=="https:"?"https://"+_GUL+":"+_SGPT:"http://"+_GUL+":"+_GPT;if( _bn.indexOf("Netscape") &gt; -1 || _bn=="Mozilla"){ setTimeout("_AIMG.src = _PR+'/?cookie';",1); } else{ _AIMG.src = _PR+'/?cookie'; };
# 	document.writeln("&lt;scr"+"ipt language='javascript' src='/js/counter_kr.js?v=2'&gt;&lt;/scr"+"ipt&gt;");
# 	}
# 	</script><script language="javascript" src="/js/counter_kr.js?v=2"></script>
# <noscript>&lt;img src='http://count.president.go.kr:80/?uid=11&amp;je=n&amp;' border=0 width=0 height=0&gt;</noscript>
# <!-- AceCounter Log Gathering Script End -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-112394055-1"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());gtag('config', 'UA-112394055-1');
# 	</script>
# <div class="ui-datepicker ui-widget ui-widget-content ui-helper-clearfix ui-corner-all" id="ui-datepicker-div"></div></body></html>

# %% [markdown]
# # html로부터 제목, 세부페이지 정보 가져오기

# %%
Date = []
Title = []
Url = []

try:
    for i in range(len(data3)):

        for r in list(range(10)):
            date = data3[i].find_all("ul", "PG_peti_list")[r].find("li").text
            date2 = re.search("\d{4}[-]\d{2}[-]\d{2}", date).group().replace("-", "")
            date3 = datetime.strptime(date2, '%Y%m%d')

            title = data3[i].find_all("div", "PG_contens_pd_list")[r].find("h2").text

            url2 = data3[i].find_all("div", "PG_contens_pd_list")[r].find("a")["href"]
            url3 = "https://www1.president.go.kr"+ url2

            Date.append(date3)
            Title.append(title)
            Url.append(url3)
        if i % 20 ==0:
            print(i)
    df1 = pd.DataFrame({"날짜": Date, "제목": Title, "주소": Url})
    print("분석 완료! 결과값: df1")
            
except:
    print("분석 실패!")
# Out:
# 0
# 분석 완료! 결과값: df1

# %%
df1
# Out:
#            날짜                                                 제목  \
# 0  2018-10-30                            모든 학교의 화장, 복장 규제를 없애주세요
# 1  2018-10-21                                              교복 폐지
# 2  2018-10-19                                   비효율성인 교복을 없애주세요.
# 3  2018-10-14                  안녕하세요. 노숙자 분이 부모님이라고 생각해주시고 봐주세요.
# 4  2018-10-13              진짜 너무한 거 아닌가요? 학생도 선생님과 똑같이 추위를 느낍니다.
# 5  2018-10-11                                  평범한 사람의 판단에 맡깁니다.
# 6  2018-10-05                    서울 교육청 두발 자율화 반대, 교복 개정 및 보안 찬성
# 7  2018-10-03                          대구  모든중학교에  사복입을수 있게 해주세료
# 8  2018-09-27               문재인 대통령께 표창 받은 병원에서 겪은 이상한 일들을 알립니다.
# 9  2018-09-27                                        아기고양이 살려주세요
# 10 2018-09-04                    이정도가 사람이 먼저다 입니까 그래서 교육부장관을....
# 11 2018-08-28                            평촌 갈산동 대안여중 교장의 성대한 퇴임식
# 12 2018-08-20                                        한전, 이래도 되나?
# 13 2018-08-16                             여학생의 교복은 불편한점이 너무 많습니다
# 14 2018-08-10                  농수산물 공판장에 냉난방기기 설치를 할 수 있도록 도와주세요
# 15 2018-08-07                                      전기사용에 관하여 고민.
# 16 2018-07-19                     어린이통학버스 주차시  창문열어놓고 물과 담요 비치하기
# 17 2018-07-02                                   제주도에 애 셋낳은 엄마예요.
# 18 2018-07-01                   군대 혁신은 이번 정권에서 즉각적으로 이루어 져야 합니다.
# 19 2018-06-28                                    학교에서 조치를 취해주세요.
# 20 2018-06-14  조리원 얼굴에 찬물 뿌리고 갑질한 충남 아산시교육청 신창 중학교 무기계약직 영양사 ...
# 21 2018-06-12                                  충남 아산시 교육청 고발합니다.
# 22 2018-06-04                                            이재민 안식처
# 23 2018-05-31      학교 급식 조리원 얼굴에 찬물 뿌리면서 갑질하는 무기계약직 영양사 처벌 바랍니다.
# 24 2018-05-27                         국공립 및 공공 도서관 온도제한을 완화해 주세요
# 25 2018-05-26  조리종사원 얼굴에 고의로 물뿌리고 조리원의 음식.컵을 집어 던지고 갑질한 무기계약직...
# 26 2018-05-25       (한번만 봐주세요).학교급식 조리원 얼굴에 물뿌린 비정규직 영양사 처벌해주세요!
# 27 2018-05-22  학교비정규직의 정규직화 반대합니다.위탁 급식법 만들어 주세요.교육공무직원들은 학교에...
# 28 2018-05-21  학교비정규직에 무기계약직 폐지 요구합니다.파업 행위시 징계 할수 있는 법 제정 요구...
# 29 2018-05-20  국립학교 학교 비정규직의 정규직화 반대 및 처우 개선 반대!! 식사비지원을 반대합니...
# ..        ...                                                ...
# 40 2018-03-15                                  중학교/고등학교 학교 규칙 관련
# 41 2018-03-08               현재 학생교복을 남녀 구분없이 모두 티셔츠와 바지로 통일해 주세요
# 42 2018-03-04                            중학교, 고등학교 학생들에게 자유를 주세요
# 43 2018-03-04                    '몽키 하우스 조사 해서 피해자 한을 풀어야 됩니다. '
# 44 2018-03-01                             입양이아니어도 친자포기할수 있게 해주세요
# 45 2018-02-28                                    제주도 학생 인권 조례 제정
# 46 2018-02-21                               히터좀 틀어주세요 그리고 급식좀 제발
# 47 2018-02-20                                            학생인권 존중
# 48 2018-02-17                           대한민국 중 고등학교 학칙 제발 바꿔주세요.
# 49 2018-02-11                                          교복을 없애주세요
# 50 2018-02-09                                     평창올림픽 자원봉사자 처우
# 51 2018-02-08                            대한민국 여자 중-고등학생들을 지켜주세요.
# 52 2018-02-08                                             학교와 학생
# 53 2018-02-06                              평창동계올림픽 기념품으로 은박담요 제공
# 54 2018-02-06            평창동계올림픽 개·폐회식장 방한 대책 허술…"역대 최악 개회식될 듯"
# 55 2018-02-06                             "텀블러 안됩니다"평창올림픽 금지 품목들
# 56 2018-02-04                              학생인권신장을 위한 대책을 마련해주세요
# 57 2018-02-03             교복을 치마&바지 중에서 하나를 고르도록 여학생들에게 권리를 주세요.
# 58 2018-02-01                               학교 온도가 적절치 못한 것 같습니다
# 59 2018-01-31                            이 혹한에 여학생들이 치마를 입어야합니까?
# 60 2018-01-28                            인천공항 노동자환경 처우 개선 시급합니다.
# 61 2018-01-27                      150명 여성에게 용변기 1대 뿐…"가축우리에 산다"
# 62 2018-01-26                     밀양 세종병원 병상 95개인데 의사2명, 간호사 7명
# 63 2018-01-26                  인천공항 비정규직 청소노동자들의 노동환경을 개선해 주십시요.
# 64 2018-01-22                              교장을 학생들이 뽑을 수 있게 해주세요
# 65 2018-01-22                  학생들에게 교육감과 교장을 직접뽑을수 있는 투표권을 주십시오
# 66 2018-01-22                                  평창 올림픽 스타디움 대책 마련
# 67 2018-01-17                                   지진,화재,재난대비책요망제안서
# 68 2018-01-11                                 대한민국 여학생 교복 바지로 통합
# 69 2018-01-02  요양병원/요양원 환자 인권 침해 방지를 위해 병실 내 무인감시카메라 설치 의무화를 ...
#
#                                                주소
# 0   https://www1.president.go.kr/petitions/425617
# 1   https://www1.president.go.kr/petitions/413931
# 2   https://www1.president.go.kr/petitions/411058
# 3   https://www1.president.go.kr/petitions/406214
# 4   https://www1.president.go.kr/petitions/405978
# 5   https://www1.president.go.kr/petitions/403890
# 6   https://www1.president.go.kr/petitions/398626
# 7   https://www1.president.go.kr/petitions/396929
# 8   https://www1.president.go.kr/petitions/391268
# 9   https://www1.president.go.kr/petitions/391048
# 10  https://www1.president.go.kr/petitions/365264
# 11  https://www1.president.go.kr/petitions/358007
# 12  https://www1.president.go.kr/petitions/348094
# 13  https://www1.president.go.kr/petitions/343335
# 14  https://www1.president.go.kr/petitions/335303
# 15  https://www1.president.go.kr/petitions/331667
# 16  https://www1.president.go.kr/petitions/311298
# 17  https://www1.president.go.kr/petitions/293604
# 18  https://www1.president.go.kr/petitions/291918
# 19  https://www1.president.go.kr/petitions/288052
# 20  https://www1.president.go.kr/petitions/270633
# 21  https://www1.president.go.kr/petitions/269240
# 22  https://www1.president.go.kr/petitions/261241
# 23  https://www1.president.go.kr/petitions/256100
# 24  https://www1.president.go.kr/petitions/245348
# 25  https://www1.president.go.kr/petitions/244600
# 26  https://www1.president.go.kr/petitions/243776
# 27  https://www1.president.go.kr/petitions/240303
# 28  https://www1.president.go.kr/petitions/238993
# 29  https://www1.president.go.kr/petitions/237998
# ..                                            ...
# 40  https://www1.president.go.kr/petitions/167147
# 41  https://www1.president.go.kr/petitions/161772
# 42  https://www1.president.go.kr/petitions/157830
# 43  https://www1.president.go.kr/petitions/157378
# 44  https://www1.president.go.kr/petitions/154984
# 45  https://www1.president.go.kr/petitions/153530
# 46  https://www1.president.go.kr/petitions/145350
# 47  https://www1.president.go.kr/petitions/143738
# 48  https://www1.president.go.kr/petitions/140992
# 49  https://www1.president.go.kr/petitions/136718
# 50  https://www1.president.go.kr/petitions/135141
# 51  https://www1.president.go.kr/petitions/134638
# 52  https://www1.president.go.kr/petitions/134052
# 53  https://www1.president.go.kr/petitions/131043
# 54  https://www1.president.go.kr/petitions/130420
# 55  https://www1.president.go.kr/petitions/129805
# 56  https://www1.president.go.kr/petitions/127453
# 57  https://www1.president.go.kr/petitions/126601
# 58  https://www1.president.go.kr/petitions/124976
# 59  https://www1.president.go.kr/petitions/123303
# 60  https://www1.president.go.kr/petitions/119054
# 61  https://www1.president.go.kr/petitions/116007
# 62  https://www1.president.go.kr/petitions/115325
# 63  https://www1.president.go.kr/petitions/114525
# 64  https://www1.president.go.kr/petitions/108245
# 65  https://www1.president.go.kr/petitions/108050
# 66  https://www1.president.go.kr/petitions/107362
# 67  https://www1.president.go.kr/petitions/101177
# 68   https://www1.president.go.kr/petitions/88818
# 69   https://www1.president.go.kr/petitions/78634
#
# [70 rows x 3 columns]

# %%
df1.to_csv("data/4th1.csv", sep=',', encoding='UTF-8')

# %% [markdown]
# # 세부 페이지에서 내용 가져오기

# %%
P = []
T = []

try:
    for i in range(len(df1["주소"])):
        url = df1["주소"].values[i]
        html = urlopen(url)
        soup = BeautifulSoup(html, "lxml")

        p = soup.find_all("h2", "petitionsView_count")[0].find("span").text
        P.append(p)

        t = soup.find_all("div", "View_write")[0].text.replace("\r", "").replace("\n", "").replace("\t", "")
        T.append(t)

        if i%20 ==0:
            print(i)
            
except:
    print("본문 크롤링 실패!")
    
df1["청원인"] = P
df1["본문"] = T
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660

# %%
# 파일로 저장
df1.to_csv("data/4th2.csv", sep=',', encoding='UTF-8')

# %%
import nltk
from konlpy.tag import Hannanum
import pandas as pd
from time import sleep
import datetime 
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib notebook
han = Hannanum()
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df1 = pd.read_csv("./4th2.csv", encoding = "utf-8")
df2 = pd.read_csv("./work2.csv", encoding = "utf-8")

# %% [markdown]
# # 4차산업 형태소 분석

# %%
title4th = []
for i in range(10):
    start = 0 + 100*i
    end = 100 + 100*i
    text = df1["제목"][start:end]
    textfull = ". ".join(text)
    title4th.append(textfull)

# %%
nouns4th = []
a = 0

for i in title4th:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nouns4th.extend(nountemp)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10

# %%
one_words2 = []
tow_words2 = []
etc_words2 = []
for noun in nouns4th:
    if len(noun) == 1:
        one_words2.append(noun)
    elif len(noun) == 2:
        tow_words2.append(noun)
    else:
        etc_words2.append(noun)
        
len(one_words2), len(tow_words2), len(etc_words2)
# Out:
# (398, 2192, 2398)

# %%
stop_words_4th = ['청원','정부','한국','문재','대통령님']
stop_words_4th.extend(one_words2)
len(stop_words_4th)
# Out:
# 403

# %%
fourth_nouns = [word for word in nouns4th if word not in stop_words_4th]
len(fourth_nouns)
# Out:
# 4449

# %%
fourth_nouns = nltk.Text(fourth_nouns, name = "일자리")
fourth_noun_common = fourth_nouns.vocab().most_common()

# %%
plt.figure(figsize=(10,4))
fourth_nouns.plot(30)
plt.show()

# %%
fourth_nouns.collocations(window_size=3)
# Out:
# 국제선 계류장; 계류장 항공기; 계류장 항공기소음; 국제선 항공기소음; 항공기소음 항공기; 기본적 생활권; 김포공항 계류장;
# 김포공항 국제선; 가상화폐 거래소; 제작자및 유포자; 김상조 공정거래위원장; 실타래 느낀점; 장려정책 쪽박차; 제정해
# 암호화페; 채굴회사 대체에너지; 청년실업문제의얽힌 느낀점; 청년실업문제의얽힌 실타래; 치기공사 졸업생; 금감원장 금융위원장;
# 원자력 발전소

# %%
fw = dict(fourth_noun_common)
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(fw)
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# # 일자리 형태소 분석

# %%
titlework = []
for i in range(120):
    start = 0 + 100*i
    end = 100 + 100*i
    text = df2["제목"][start:end]
    textfull = ". ".join(text)
    titlework.append(textfull)

# %%
nounswork = []
a = 0

for i in titlework:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nounswork.extend(nountemp)

nouns2 = ", ".join(nounswork)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10
# 형태소 분석 시작11
# 형태소 분석 시작12
# 형태소 분석 시작13
# 형태소 분석 시작14
# 형태소 분석 시작15
# 형태소 분석 시작16
# 형태소 분석 시작17
# 형태소 분석 시작18
# 형태소 분석 시작19
# 형태소 분석 시작20
# 형태소 분석 시작21
# 형태소 분석 시작22
# 형태소 분석 시작23
# 형태소 분석 시작24
# 형태소 분석 시작25
# 형태소 분석 시작26
# 형태소 분석 시작27
# 형태소 분석 시작28
# 형태소 분석 시작29
# 형태소 분석 시작30
# 형태소 분석 시작31
# 형태소 분석 시작32
# 형태소 분석 시작33
# 형태소 분석 시작34
# 형태소 분석 시작35
# 형태소 분석 시작36
# 형태소 분석 시작37
# 형태소 분석 시작38
# 형태소 분석 시작39
# 형태소 분석 시작40
# 형태소 분석 시작41
# 형태소 분석 시작42
# 형태소 분석 시작43
# 형태소 분석 시작44
# 형태소 분석 시작45
# 형태소 분석 시작46
# 형태소 분석 시작47
# 형태소 분석 시작48
# 형태소 분석 시작49
# 형태소 분석 시작50
# 형태소 분석 시작51
# 형태소 분석 시작52
# 형태소 분석 시작53
# 형태소 분석 시작54
# 형태소 분석 시작55
# 형태소 분석 시작56
# 형태소 분석 시작57
# 형태소 분석 시작58
# 형태소 분석 시작59
# 형태소 분석 시작60
# 형태소 분석 시작61
# 형태소 분석 시작62
# 형태소 분석 시작63
# 형태소 분석 시작64
# 형태소 분석 시작65
# 형태소 분석 시작66
# 형태소 분석 시작67
# 형태소 분석 시작68
# 형태소 분석 시작69
# 형태소 분석 시작70
# 형태소 분석 시작71
# 형태소 분석 시작72
# 형태소 분석 시작73
# 형태소 분석 시작74
# 형태소 분석 시작75
# 형태소 분석 시작76
# 형태소 분석 시작77
# 형태소 분석 시작78
# 형태소 분석 시작79
# 형태소 분석 시작80
# 형태소 분석 시작81
# 형태소 분석 시작82
# 형태소 분석 시작83
# 형태소 분석 시작84
# 형태소 분석 시작85
# 형태소 분석 시작86
# 형태소 분석 시작87
# 형태소 분석 시작88
# 형태소 분석 시작89
# 형태소 분석 시작90
# 형태소 분석 시작91
# 형태소 분석 시작92
# 형태소 분석 시작93
# 형태소 분석 시작94
# 형태소 분석 시작95
# 형태소 분석 시작96
# 형태소 분석 시작97
# 형태소 분석 시작98
# 형태소 분석 시작99
# 형태소 분석 시작100
# 형태소 분석 시작101
# 형태소 분석 시작102
# 형태소 분석 시작103
# 형태소 분석 시작104
# 형태소 분석 시작105
# 형태소 분석 시작106
# 형태소 분석 시작107
# 형태소 분석 시작108
# 형태소 분석 시작109
# 형태소 분석 시작110
# 형태소 분석 시작111
# 형태소 분석 시작112
# 형태소 분석 시작113
# 형태소 분석 시작114
# 형태소 분석 시작115
# 형태소 분석 시작116
# 형태소 분석 시작117
# 형태소 분석 시작118
# 형태소 분석 시작119
# 형태소 분석 시작120

# %%
one_words1 = []
tow_words1= []
etc_words1= []
for noun in nounswork:
    if len(noun) == 1:
        one_words1.append(noun)
    elif len(noun) == 2:
        tow_words1.append(noun)
    else:
        etc_words1.append(noun)
        
len(one_words1), len(tow_words1), len(etc_words1)
# Out:
# (4197, 20180, 26546)

# %%
stop_words_work = ["일자리", '청원','정부','한국','문재','대통령님']
stop_words_work.extend(one_words1)
len(stop_words_work)
work_nouns = [word for word in nounswork if word not in stop_words_work]
len(work_nouns)
# Out:
# 43785

# %%
work_nouns1 = nltk.Text(work_nouns, name = "일자리")
work_noun_common = work_nouns1.vocab().most_common()

# %%
plt.figure(figsize=(10,4))
work_nouns1.plot(30)
plt.show()

# %%
work_nouns1.collocations(window_size=3)
# Out:
# 기초연금지급 대선공약; 정규직 정규직; ◈문재인정부 근본적; 파견직 직접고용; 가상화폐 거래소; 다산신도시 실버택배; 금감원
# 회계위반고시; 공영방송 파견직; 은행원 퇴직금; 공공부문 정규직; ☻문대통령 기초연금지급; ☻문대통령 대선공약; 공공기관
# 지방이전; 민간어린이집 가정어린이집; 불법난민 불법체류; 어린이집 유치원; 회계위반고시 주주들; 삼성바이로직스 주주들;
# 소상공인진흥공단 신용보증재단; 소상공인진흥공단 중소기업산업진흥원

# %%
df2 = pd.read_csv("./work2.csv", encoding = "utf-8")

# %%
ww = dict(work_noun_common)
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(ww)
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# # 일자리 키워드별 분석-최저임금

# %%
titlework = []

for i in df2["제목"]:
    if "최저임금" in i:
        titlework.append(i)
        
    else:
        pass

# %%
nounswork = []
a = 0

for i in titlework:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nounswork.extend(nountemp)

nouns2 = ", ".join(nounswork)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10
# 형태소 분석 시작11
# 형태소 분석 시작12
# 형태소 분석 시작13
# 형태소 분석 시작14
# 형태소 분석 시작15
# 형태소 분석 시작16
# 형태소 분석 시작17
# 형태소 분석 시작18
# 형태소 분석 시작19
# 형태소 분석 시작20
# 형태소 분석 시작21
# 형태소 분석 시작22
# 형태소 분석 시작23
# 형태소 분석 시작24
# 형태소 분석 시작25
# 형태소 분석 시작26
# 형태소 분석 시작27
# 형태소 분석 시작28
# 형태소 분석 시작29
# 형태소 분석 시작30
# 형태소 분석 시작31
# 형태소 분석 시작32
# 형태소 분석 시작33
# 형태소 분석 시작34
# 형태소 분석 시작35
# 형태소 분석 시작36
# 형태소 분석 시작37
# 형태소 분석 시작38
# 형태소 분석 시작39
# 형태소 분석 시작40
# 형태소 분석 시작41
# 형태소 분석 시작42
# 형태소 분석 시작43
# 형태소 분석 시작44
# 형태소 분석 시작45
# 형태소 분석 시작46
# 형태소 분석 시작47
# 형태소 분석 시작48
# 형태소 분석 시작49
# 형태소 분석 시작50
# 형태소 분석 시작51
# 형태소 분석 시작52
# 형태소 분석 시작53
# 형태소 분석 시작54
# 형태소 분석 시작55
# 형태소 분석 시작56
# 형태소 분석 시작57
# 형태소 분석 시작58
# 형태소 분석 시작59
# 형태소 분석 시작60
# 형태소 분석 시작61
# 형태소 분석 시작62
# 형태소 분석 시작63
# 형태소 분석 시작64
# 형태소 분석 시작65
# 형태소 분석 시작66
# 형태소 분석 시작67
# 형태소 분석 시작68
# 형태소 분석 시작69
# 형태소 분석 시작70
# 형태소 분석 시작71
# 형태소 분석 시작72
# 형태소 분석 시작73
# 형태소 분석 시작74
# 형태소 분석 시작75
# 형태소 분석 시작76
# 형태소 분석 시작77
# 형태소 분석 시작78
# 형태소 분석 시작79
# 형태소 분석 시작80
# 형태소 분석 시작81
# 형태소 분석 시작82
# 형태소 분석 시작83
# 형태소 분석 시작84
# 형태소 분석 시작85
# 형태소 분석 시작86
# 형태소 분석 시작87
# 형태소 분석 시작88
# 형태소 분석 시작89
# 형태소 분석 시작90
# 형태소 분석 시작91
# 형태소 분석 시작92
# 형태소 분석 시작93
# 형태소 분석 시작94
# 형태소 분석 시작95
# 형태소 분석 시작96
# 형태소 분석 시작97
# 형태소 분석 시작98
# 형태소 분석 시작99
# 형태소 분석 시작100
# 형태소 분석 시작101
# 형태소 분석 시작102
# 형태소 분석 시작103
# 형태소 분석 시작104
# 형태소 분석 시작105
# 형태소 분석 시작106
# 형태소 분석 시작107
# 형태소 분석 시작108
# 형태소 분석 시작109
# 형태소 분석 시작110
# 형태소 분석 시작111
# 형태소 분석 시작112
# 형태소 분석 시작113
# 형태소 분석 시작114
# 형태소 분석 시작115
# 형태소 분석 시작116
# 형태소 분석 시작117
# 형태소 분석 시작118
# 형태소 분석 시작119
# 형태소 분석 시작120
# 형태소 분석 시작121
# 형태소 분석 시작122
# 형태소 분석 시작123
# 형태소 분석 시작124
# 형태소 분석 시작125
# 형태소 분석 시작126
# 형태소 분석 시작127
# 형태소 분석 시작128
# 형태소 분석 시작129
# 형태소 분석 시작130
# 형태소 분석 시작131
# 형태소 분석 시작132
# 형태소 분석 시작133
# 형태소 분석 시작134
# 형태소 분석 시작135
# 형태소 분석 시작136
# 형태소 분석 시작137
# 형태소 분석 시작138
# 형태소 분석 시작139
# 형태소 분석 시작140
# 형태소 분석 시작141
# 형태소 분석 시작142
# 형태소 분석 시작143
# 형태소 분석 시작144
# 형태소 분석 시작145
# 형태소 분석 시작146
# 형태소 분석 시작147
# 형태소 분석 시작148
# 형태소 분석 시작149
# 형태소 분석 시작150
# 형태소 분석 시작151
# 형태소 분석 시작152
# 형태소 분석 시작153
# 형태소 분석 시작154
# 형태소 분석 시작155
# 형태소 분석 시작156
# 형태소 분석 시작157
# 형태소 분석 시작158
# 형태소 분석 시작159
# 형태소 분석 시작160
# 형태소 분석 시작161
# 형태소 분석 시작162
# 형태소 분석 시작163
# 형태소 분석 시작164
# 형태소 분석 시작165
# 형태소 분석 시작166
# 형태소 분석 시작167
# 형태소 분석 시작168
# 형태소 분석 시작169
# 형태소 분석 시작170
# 형태소 분석 시작171
# 형태소 분석 시작172
# 형태소 분석 시작173
# 형태소 분석 시작174
# 형태소 분석 시작175
# 형태소 분석 시작176
# 형태소 분석 시작177
# 형태소 분석 시작178
# 형태소 분석 시작179
# 형태소 분석 시작180
# 형태소 분석 시작181
# 형태소 분석 시작182
# 형태소 분석 시작183
# 형태소 분석 시작184
# 형태소 분석 시작185
# 형태소 분석 시작186
# 형태소 분석 시작187
# 형태소 분석 시작188
# 형태소 분석 시작189
# 형태소 분석 시작190
# 형태소 분석 시작191
# 형태소 분석 시작192
# 형태소 분석 시작193
# 형태소 분석 시작194
# 형태소 분석 시작195
# 형태소 분석 시작196
# 형태소 분석 시작197
# 형태소 분석 시작198
# 형태소 분석 시작199
# 형태소 분석 시작200
# 형태소 분석 시작201
# 형태소 분석 시작202
# 형태소 분석 시작203
# 형태소 분석 시작204
# 형태소 분석 시작205
# 형태소 분석 시작206
# 형태소 분석 시작207
# 형태소 분석 시작208
# 형태소 분석 시작209
# 형태소 분석 시작210
# 형태소 분석 시작211
# 형태소 분석 시작212
# 형태소 분석 시작213
# 형태소 분석 시작214
# 형태소 분석 시작215
# 형태소 분석 시작216
# 형태소 분석 시작217
# 형태소 분석 시작218
# 형태소 분석 시작219
# 형태소 분석 시작220
# 형태소 분석 시작221
# 형태소 분석 시작222
# 형태소 분석 시작223
# 형태소 분석 시작224
# 형태소 분석 시작225
# 형태소 분석 시작226
# 형태소 분석 시작227
# 형태소 분석 시작228
# 형태소 분석 시작229
# 형태소 분석 시작230
# 형태소 분석 시작231
# 형태소 분석 시작232
# 형태소 분석 시작233
# 형태소 분석 시작234
# 형태소 분석 시작235
# 형태소 분석 시작236
# 형태소 분석 시작237
# 형태소 분석 시작238
# 형태소 분석 시작239
# 형태소 분석 시작240
# 형태소 분석 시작241
# 형태소 분석 시작242
# 형태소 분석 시작243
# 형태소 분석 시작244
# 형태소 분석 시작245
# 형태소 분석 시작246
# 형태소 분석 시작247
# 형태소 분석 시작248
# 형태소 분석 시작249
# 형태소 분석 시작250
# 형태소 분석 시작251
# 형태소 분석 시작252
# 형태소 분석 시작253
# 형태소 분석 시작254
# 형태소 분석 시작255
# 형태소 분석 시작256
# 형태소 분석 시작257
# 형태소 분석 시작258
# 형태소 분석 시작259
# 형태소 분석 시작260
# 형태소 분석 시작261
# 형태소 분석 시작262
# 형태소 분석 시작263
# 형태소 분석 시작264
# 형태소 분석 시작265
# 형태소 분석 시작266
# 형태소 분석 시작267
# 형태소 분석 시작268
# 형태소 분석 시작269
# 형태소 분석 시작270
# 형태소 분석 시작271
# 형태소 분석 시작272
# 형태소 분석 시작273
# 형태소 분석 시작274
# 형태소 분석 시작275
# 형태소 분석 시작276
# 형태소 분석 시작277
# 형태소 분석 시작278
# 형태소 분석 시작279
# 형태소 분석 시작280
# 형태소 분석 시작281
# 형태소 분석 시작282
# 형태소 분석 시작283
# 형태소 분석 시작284
# 형태소 분석 시작285
# 형태소 분석 시작286
# 형태소 분석 시작287
# 형태소 분석 시작288
# 형태소 분석 시작289
# 형태소 분석 시작290
# 형태소 분석 시작291
# 형태소 분석 시작292
# 형태소 분석 시작293
# 형태소 분석 시작294
# 형태소 분석 시작295
# 형태소 분석 시작296
# 형태소 분석 시작297
# 형태소 분석 시작298
# 형태소 분석 시작299
# 형태소 분석 시작300
# 형태소 분석 시작301
# 형태소 분석 시작302
# 형태소 분석 시작303
# 형태소 분석 시작304
# 형태소 분석 시작305
# 형태소 분석 시작306
# 형태소 분석 시작307
# 형태소 분석 시작308
# 형태소 분석 시작309
# 형태소 분석 시작310
# 형태소 분석 시작311
# 형태소 분석 시작312
# 형태소 분석 시작313
# 형태소 분석 시작314
# 형태소 분석 시작315
# 형태소 분석 시작316
# 형태소 분석 시작317
# 형태소 분석 시작318
# 형태소 분석 시작319
# 형태소 분석 시작320
# 형태소 분석 시작321
# 형태소 분석 시작322
# 형태소 분석 시작323
# 형태소 분석 시작324
# 형태소 분석 시작325
# 형태소 분석 시작326
# 형태소 분석 시작327
# 형태소 분석 시작328
# 형태소 분석 시작329
# 형태소 분석 시작330
# 형태소 분석 시작331
# 형태소 분석 시작332
# 형태소 분석 시작333
# 형태소 분석 시작334
# 형태소 분석 시작335
# 형태소 분석 시작336
# 형태소 분석 시작337
# 형태소 분석 시작338
# 형태소 분석 시작339
# 형태소 분석 시작340
# 형태소 분석 시작341
# 형태소 분석 시작342
# 형태소 분석 시작343
# 형태소 분석 시작344
# 형태소 분석 시작345
# 형태소 분석 시작346
# 형태소 분석 시작347
# 형태소 분석 시작348
# 형태소 분석 시작349
# 형태소 분석 시작350
# 형태소 분석 시작351
# 형태소 분석 시작352
# 형태소 분석 시작353
# 형태소 분석 시작354
# 형태소 분석 시작355
# 형태소 분석 시작356
# 형태소 분석 시작357
# 형태소 분석 시작358
# 형태소 분석 시작359
# 형태소 분석 시작360
# 형태소 분석 시작361
# 형태소 분석 시작362
# 형태소 분석 시작363
# 형태소 분석 시작364
# 형태소 분석 시작365
# 형태소 분석 시작366
# 형태소 분석 시작367
# 형태소 분석 시작368
# 형태소 분석 시작369
# 형태소 분석 시작370
# 형태소 분석 시작371
# 형태소 분석 시작372
# 형태소 분석 시작373
# 형태소 분석 시작374
# 형태소 분석 시작375
# 형태소 분석 시작376
# 형태소 분석 시작377
# 형태소 분석 시작378
# 형태소 분석 시작379
# 형태소 분석 시작380
# 형태소 분석 시작381
# 형태소 분석 시작382
# 형태소 분석 시작383
# 형태소 분석 시작384
# 형태소 분석 시작385
# 형태소 분석 시작386
# 형태소 분석 시작387
# 형태소 분석 시작388
# 형태소 분석 시작389
# 형태소 분석 시작390
# 형태소 분석 시작391
# 형태소 분석 시작392
# 형태소 분석 시작393
# 형태소 분석 시작394
# 형태소 분석 시작395
# 형태소 분석 시작396
# 형태소 분석 시작397
# 형태소 분석 시작398
# 형태소 분석 시작399
# 형태소 분석 시작400
# 형태소 분석 시작401
# 형태소 분석 시작402
# 형태소 분석 시작403
# 형태소 분석 시작404
# 형태소 분석 시작405
# 형태소 분석 시작406
# 형태소 분석 시작407
# 형태소 분석 시작408
# 형태소 분석 시작409
# 형태소 분석 시작410
# 형태소 분석 시작411
# 형태소 분석 시작412
# 형태소 분석 시작413
# 형태소 분석 시작414
# 형태소 분석 시작415
# 형태소 분석 시작416
# 형태소 분석 시작417
# 형태소 분석 시작418
# 형태소 분석 시작419
# 형태소 분석 시작420
# 형태소 분석 시작421
# 형태소 분석 시작422
# 형태소 분석 시작423
# 형태소 분석 시작424
# 형태소 분석 시작425
# 형태소 분석 시작426
# 형태소 분석 시작427
# 형태소 분석 시작428
# 형태소 분석 시작429
# 형태소 분석 시작430
# 형태소 분석 시작431
# 형태소 분석 시작432
# 형태소 분석 시작433
# 형태소 분석 시작434
# 형태소 분석 시작435
# 형태소 분석 시작436
# 형태소 분석 시작437

# %%
one_words3= []
tow_words1= []
etc_words1= []
for noun in nounswork:
    if len(noun) == 1:
        one_words1.append(noun)
    elif len(noun) == 2:
        tow_words1.append(noun)
    else:
        etc_words1.append(noun)
        
len(one_words3), len(tow_words1), len(etc_words1)
# Out:
# (0, 645, 1125)

# %%
stop_words_work = ["일자리", '청원','정부','한국','문재','대통령님', "최저임금"]
stop_words_work.extend(one_words1)
len(stop_words_work)

work_nouns = [word for word in nounswork if word not in stop_words_work]
len(work_nouns)
# Out:
# 1350

# %%
work_nouns1 = nltk.Text(work_nouns, name = "일자리")
work_noun_common = work_nouns1.vocab().most_common()
plt.figure(figsize=(10,4))
work_nouns1.plot(30)
plt.show()

# %%
work_nouns1.collocations(window_size=3)
# Out:
# 거짓말 최저임금에관한의견; 외국노동자 계약직; 장애인최저임금 적용제외; 당신들 최순실; 일방적 나라다운; 최저임금인상 서민들

# %%
ww = dict(work_noun_common)
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(ww)

plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# # 일자리 키워드별 분석-정규직

# %%
titlework2 = []

for i in df2["제목"]:
    if "정규직" in i:
        titlework.append(i)
        
    else:
        pass
    
    nounswork2 = []
    
    
a = 0

for i in titlework:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nounswork.extend(nountemp)

nouns2 = ", ".join(nounswork)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10
# 형태소 분석 시작11
# 형태소 분석 시작12
# 형태소 분석 시작13
# 형태소 분석 시작14
# 형태소 분석 시작15
# 형태소 분석 시작16
# 형태소 분석 시작17
# 형태소 분석 시작18
# 형태소 분석 시작19
# 형태소 분석 시작20
# 형태소 분석 시작21
# 형태소 분석 시작22
# 형태소 분석 시작23
# 형태소 분석 시작24
# 형태소 분석 시작25
# 형태소 분석 시작26
# 형태소 분석 시작27
# 형태소 분석 시작28
# 형태소 분석 시작29
# 형태소 분석 시작30
# 형태소 분석 시작31
# 형태소 분석 시작32
# 형태소 분석 시작33
# 형태소 분석 시작34
# 형태소 분석 시작35
# 형태소 분석 시작36
# 형태소 분석 시작37
# 형태소 분석 시작38
# 형태소 분석 시작39
# 형태소 분석 시작40
# 형태소 분석 시작41
# 형태소 분석 시작42
# 형태소 분석 시작43
# 형태소 분석 시작44
# 형태소 분석 시작45
# 형태소 분석 시작46
# 형태소 분석 시작47
# 형태소 분석 시작48
# 형태소 분석 시작49
# 형태소 분석 시작50
# 형태소 분석 시작51
# 형태소 분석 시작52
# 형태소 분석 시작53
# 형태소 분석 시작54
# 형태소 분석 시작55
# 형태소 분석 시작56
# 형태소 분석 시작57
# 형태소 분석 시작58
# 형태소 분석 시작59
# 형태소 분석 시작60
# 형태소 분석 시작61
# 형태소 분석 시작62
# 형태소 분석 시작63
# 형태소 분석 시작64
# 형태소 분석 시작65
# 형태소 분석 시작66
# 형태소 분석 시작67
# 형태소 분석 시작68
# 형태소 분석 시작69
# 형태소 분석 시작70
# 형태소 분석 시작71
# 형태소 분석 시작72
# 형태소 분석 시작73
# 형태소 분석 시작74
# 형태소 분석 시작75
# 형태소 분석 시작76
# 형태소 분석 시작77
# 형태소 분석 시작78
# 형태소 분석 시작79
# 형태소 분석 시작80
# 형태소 분석 시작81
# 형태소 분석 시작82
# 형태소 분석 시작83
# 형태소 분석 시작84
# 형태소 분석 시작85
# 형태소 분석 시작86
# 형태소 분석 시작87
# 형태소 분석 시작88
# 형태소 분석 시작89
# 형태소 분석 시작90
# 형태소 분석 시작91
# 형태소 분석 시작92
# 형태소 분석 시작93
# 형태소 분석 시작94
# 형태소 분석 시작95
# 형태소 분석 시작96
# 형태소 분석 시작97
# 형태소 분석 시작98
# 형태소 분석 시작99
# 형태소 분석 시작100
# 형태소 분석 시작101
# 형태소 분석 시작102
# 형태소 분석 시작103
# 형태소 분석 시작104
# 형태소 분석 시작105
# 형태소 분석 시작106
# 형태소 분석 시작107
# 형태소 분석 시작108
# 형태소 분석 시작109
# 형태소 분석 시작110
# 형태소 분석 시작111
# 형태소 분석 시작112
# 형태소 분석 시작113
# 형태소 분석 시작114
# 형태소 분석 시작115
# 형태소 분석 시작116
# 형태소 분석 시작117
# 형태소 분석 시작118
# 형태소 분석 시작119
# 형태소 분석 시작120
# 형태소 분석 시작121
# 형태소 분석 시작122
# 형태소 분석 시작123
# 형태소 분석 시작124
# 형태소 분석 시작125
# 형태소 분석 시작126
# 형태소 분석 시작127
# 형태소 분석 시작128
# 형태소 분석 시작129
# 형태소 분석 시작130
# 형태소 분석 시작131
# 형태소 분석 시작132
# 형태소 분석 시작133
# 형태소 분석 시작134
# 형태소 분석 시작135
# 형태소 분석 시작136
# 형태소 분석 시작137
# 형태소 분석 시작138
# 형태소 분석 시작139
# 형태소 분석 시작140
# 형태소 분석 시작141
# 형태소 분석 시작142
# 형태소 분석 시작143
# 형태소 분석 시작144
# 형태소 분석 시작145
# 형태소 분석 시작146
# 형태소 분석 시작147
# 형태소 분석 시작148
# 형태소 분석 시작149
# 형태소 분석 시작150
# 형태소 분석 시작151
# 형태소 분석 시작152
# 형태소 분석 시작153
# 형태소 분석 시작154
# 형태소 분석 시작155
# 형태소 분석 시작156
# 형태소 분석 시작157
# 형태소 분석 시작158
# 형태소 분석 시작159
# 형태소 분석 시작160
# 형태소 분석 시작161
# 형태소 분석 시작162
# 형태소 분석 시작163
# 형태소 분석 시작164
# 형태소 분석 시작165
# 형태소 분석 시작166
# 형태소 분석 시작167
# 형태소 분석 시작168
# 형태소 분석 시작169
# 형태소 분석 시작170
# 형태소 분석 시작171
# 형태소 분석 시작172
# 형태소 분석 시작173
# 형태소 분석 시작174
# 형태소 분석 시작175
# 형태소 분석 시작176
# 형태소 분석 시작177
# 형태소 분석 시작178
# 형태소 분석 시작179
# 형태소 분석 시작180
# 형태소 분석 시작181
# 형태소 분석 시작182
# 형태소 분석 시작183
# 형태소 분석 시작184
# 형태소 분석 시작185
# 형태소 분석 시작186
# 형태소 분석 시작187
# 형태소 분석 시작188
# 형태소 분석 시작189
# 형태소 분석 시작190
# 형태소 분석 시작191
# 형태소 분석 시작192
# 형태소 분석 시작193
# 형태소 분석 시작194
# 형태소 분석 시작195
# 형태소 분석 시작196
# 형태소 분석 시작197
# 형태소 분석 시작198
# 형태소 분석 시작199
# 형태소 분석 시작200
# 형태소 분석 시작201
# 형태소 분석 시작202
# 형태소 분석 시작203
# 형태소 분석 시작204
# 형태소 분석 시작205
# 형태소 분석 시작206
# 형태소 분석 시작207
# 형태소 분석 시작208
# 형태소 분석 시작209
# 형태소 분석 시작210
# 형태소 분석 시작211
# 형태소 분석 시작212
# 형태소 분석 시작213
# 형태소 분석 시작214
# 형태소 분석 시작215
# 형태소 분석 시작216
# 형태소 분석 시작217
# 형태소 분석 시작218
# 형태소 분석 시작219
# 형태소 분석 시작220
# 형태소 분석 시작221
# 형태소 분석 시작222
# 형태소 분석 시작223
# 형태소 분석 시작224
# 형태소 분석 시작225
# 형태소 분석 시작226
# 형태소 분석 시작227
# 형태소 분석 시작228
# 형태소 분석 시작229
# 형태소 분석 시작230
# 형태소 분석 시작231
# 형태소 분석 시작232
# 형태소 분석 시작233
# 형태소 분석 시작234
# 형태소 분석 시작235
# 형태소 분석 시작236
# 형태소 분석 시작237
# 형태소 분석 시작238
# 형태소 분석 시작239
# 형태소 분석 시작240
# 형태소 분석 시작241
# 형태소 분석 시작242
# 형태소 분석 시작243
# 형태소 분석 시작244
# 형태소 분석 시작245
# 형태소 분석 시작246
# 형태소 분석 시작247
# 형태소 분석 시작248
# 형태소 분석 시작249
# 형태소 분석 시작250
# 형태소 분석 시작251
# 형태소 분석 시작252
# 형태소 분석 시작253
# 형태소 분석 시작254
# 형태소 분석 시작255
# 형태소 분석 시작256
# 형태소 분석 시작257
# 형태소 분석 시작258
# 형태소 분석 시작259
# 형태소 분석 시작260
# 형태소 분석 시작261
# 형태소 분석 시작262
# 형태소 분석 시작263
# 형태소 분석 시작264
# 형태소 분석 시작265
# 형태소 분석 시작266
# 형태소 분석 시작267
# 형태소 분석 시작268
# 형태소 분석 시작269
# 형태소 분석 시작270
# 형태소 분석 시작271
# 형태소 분석 시작272
# 형태소 분석 시작273
# 형태소 분석 시작274
# 형태소 분석 시작275
# 형태소 분석 시작276
# 형태소 분석 시작277
# 형태소 분석 시작278
# 형태소 분석 시작279
# 형태소 분석 시작280
# 형태소 분석 시작281
# 형태소 분석 시작282
# 형태소 분석 시작283
# 형태소 분석 시작284
# 형태소 분석 시작285
# 형태소 분석 시작286
# 형태소 분석 시작287
# 형태소 분석 시작288
# 형태소 분석 시작289
# 형태소 분석 시작290
# 형태소 분석 시작291
# 형태소 분석 시작292
# 형태소 분석 시작293
# 형태소 분석 시작294
# 형태소 분석 시작295
# 형태소 분석 시작296
# 형태소 분석 시작297
# 형태소 분석 시작298
# 형태소 분석 시작299
# 형태소 분석 시작300
# 형태소 분석 시작301
# 형태소 분석 시작302
# 형태소 분석 시작303
# 형태소 분석 시작304
# 형태소 분석 시작305
# 형태소 분석 시작306
# 형태소 분석 시작307
# 형태소 분석 시작308
# 형태소 분석 시작309
# 형태소 분석 시작310
# 형태소 분석 시작311
# 형태소 분석 시작312
# 형태소 분석 시작313
# 형태소 분석 시작314
# 형태소 분석 시작315
# 형태소 분석 시작316
# 형태소 분석 시작317
# 형태소 분석 시작318
# 형태소 분석 시작319
# 형태소 분석 시작320
# 형태소 분석 시작321
# 형태소 분석 시작322
# 형태소 분석 시작323
# 형태소 분석 시작324
# 형태소 분석 시작325
# 형태소 분석 시작326
# 형태소 분석 시작327
# 형태소 분석 시작328
# 형태소 분석 시작329
# 형태소 분석 시작330
# 형태소 분석 시작331
# 형태소 분석 시작332
# 형태소 분석 시작333
# 형태소 분석 시작334
# 형태소 분석 시작335
# 형태소 분석 시작336
# 형태소 분석 시작337
# 형태소 분석 시작338
# 형태소 분석 시작339
# 형태소 분석 시작340
# 형태소 분석 시작341
# 형태소 분석 시작342
# 형태소 분석 시작343
# 형태소 분석 시작344
# 형태소 분석 시작345
# 형태소 분석 시작346
# 형태소 분석 시작347
# 형태소 분석 시작348
# 형태소 분석 시작349
# 형태소 분석 시작350
# 형태소 분석 시작351
# 형태소 분석 시작352
# 형태소 분석 시작353
# 형태소 분석 시작354
# 형태소 분석 시작355
# 형태소 분석 시작356
# 형태소 분석 시작357
# 형태소 분석 시작358
# 형태소 분석 시작359
# 형태소 분석 시작360
# 형태소 분석 시작361
# 형태소 분석 시작362
# 형태소 분석 시작363
# 형태소 분석 시작364
# 형태소 분석 시작365
# 형태소 분석 시작366
# 형태소 분석 시작367
# 형태소 분석 시작368
# 형태소 분석 시작369
# 형태소 분석 시작370
# 형태소 분석 시작371
# 형태소 분석 시작372
# 형태소 분석 시작373
# 형태소 분석 시작374
# 형태소 분석 시작375
# 형태소 분석 시작376
# 형태소 분석 시작377
# 형태소 분석 시작378
# 형태소 분석 시작379
# 형태소 분석 시작380
# 형태소 분석 시작381
# 형태소 분석 시작382
# 형태소 분석 시작383
# 형태소 분석 시작384
# 형태소 분석 시작385
# 형태소 분석 시작386
# 형태소 분석 시작387
# 형태소 분석 시작388
# 형태소 분석 시작389
# 형태소 분석 시작390
# 형태소 분석 시작391
# 형태소 분석 시작392
# 형태소 분석 시작393
# 형태소 분석 시작394
# 형태소 분석 시작395
# 형태소 분석 시작396
# 형태소 분석 시작397
# 형태소 분석 시작398
# 형태소 분석 시작399
# 형태소 분석 시작400
# 형태소 분석 시작401
# 형태소 분석 시작402
# 형태소 분석 시작403
# 형태소 분석 시작404
# 형태소 분석 시작405
# 형태소 분석 시작406
# 형태소 분석 시작407
# 형태소 분석 시작408
# 형태소 분석 시작409
# 형태소 분석 시작410
# 형태소 분석 시작411
# 형태소 분석 시작412
# 형태소 분석 시작413
# 형태소 분석 시작414
# 형태소 분석 시작415
# 형태소 분석 시작416
# 형태소 분석 시작417
# 형태소 분석 시작418
# 형태소 분석 시작419
# 형태소 분석 시작420
# 형태소 분석 시작421
# 형태소 분석 시작422
# 형태소 분석 시작423
# 형태소 분석 시작424
# 형태소 분석 시작425
# 형태소 분석 시작426
# 형태소 분석 시작427
# 형태소 분석 시작428
# 형태소 분석 시작429
# 형태소 분석 시작430
# 형태소 분석 시작431
# 형태소 분석 시작432
# 형태소 분석 시작433
# 형태소 분석 시작434
# 형태소 분석 시작435
# 형태소 분석 시작436
# 형태소 분석 시작437
# 형태소 분석 시작438
# 형태소 분석 시작439
# 형태소 분석 시작440
# 형태소 분석 시작441
# 형태소 분석 시작442
# 형태소 분석 시작443
# 형태소 분석 시작444
# 형태소 분석 시작445
# 형태소 분석 시작446
# 형태소 분석 시작447
# 형태소 분석 시작448
# 형태소 분석 시작449
# 형태소 분석 시작450
# 형태소 분석 시작451
# 형태소 분석 시작452
# 형태소 분석 시작453
# 형태소 분석 시작454
# 형태소 분석 시작455
# 형태소 분석 시작456
# 형태소 분석 시작457
# 형태소 분석 시작458
# 형태소 분석 시작459
# 형태소 분석 시작460
# 형태소 분석 시작461
# 형태소 분석 시작462
# 형태소 분석 시작463
# 형태소 분석 시작464
# 형태소 분석 시작465
# 형태소 분석 시작466
# 형태소 분석 시작467
# 형태소 분석 시작468
# 형태소 분석 시작469
# 형태소 분석 시작470
# 형태소 분석 시작471
# 형태소 분석 시작472
# 형태소 분석 시작473
# 형태소 분석 시작474
# 형태소 분석 시작475
# 형태소 분석 시작476
# 형태소 분석 시작477
# 형태소 분석 시작478
# 형태소 분석 시작479
# 형태소 분석 시작480
# 형태소 분석 시작481
# 형태소 분석 시작482
# 형태소 분석 시작483
# 형태소 분석 시작484
# 형태소 분석 시작485
# 형태소 분석 시작486
# 형태소 분석 시작487
# 형태소 분석 시작488
# 형태소 분석 시작489
# 형태소 분석 시작490
# 형태소 분석 시작491
# 형태소 분석 시작492
# 형태소 분석 시작493
# 형태소 분석 시작494
# 형태소 분석 시작495
# 형태소 분석 시작496
# 형태소 분석 시작497
# 형태소 분석 시작498
# 형태소 분석 시작499
# 형태소 분석 시작500
# 형태소 분석 시작501
# 형태소 분석 시작502
# 형태소 분석 시작503
# 형태소 분석 시작504
# 형태소 분석 시작505
# 형태소 분석 시작506
# 형태소 분석 시작507
# 형태소 분석 시작508
# 형태소 분석 시작509
# 형태소 분석 시작510
# 형태소 분석 시작511
# 형태소 분석 시작512
# 형태소 분석 시작513
# 형태소 분석 시작514
# 형태소 분석 시작515
# 형태소 분석 시작516
# 형태소 분석 시작517
# 형태소 분석 시작518
# 형태소 분석 시작519
# 형태소 분석 시작520
# 형태소 분석 시작521
# 형태소 분석 시작522
# 형태소 분석 시작523
# 형태소 분석 시작524
# 형태소 분석 시작525
# 형태소 분석 시작526
# 형태소 분석 시작527
# 형태소 분석 시작528
# 형태소 분석 시작529
# 형태소 분석 시작530
# 형태소 분석 시작531
# 형태소 분석 시작532
# 형태소 분석 시작533
# 형태소 분석 시작534
# 형태소 분석 시작535
# 형태소 분석 시작536
# 형태소 분석 시작537
# 형태소 분석 시작538
# 형태소 분석 시작539
# 형태소 분석 시작540
# 형태소 분석 시작541
# 형태소 분석 시작542
# 형태소 분석 시작543
# 형태소 분석 시작544
# 형태소 분석 시작545
# 형태소 분석 시작546
# 형태소 분석 시작547
# 형태소 분석 시작548
# 형태소 분석 시작549
# 형태소 분석 시작550
# 형태소 분석 시작551
# 형태소 분석 시작552
# 형태소 분석 시작553
# 형태소 분석 시작554
# 형태소 분석 시작555
# 형태소 분석 시작556
# 형태소 분석 시작557
# 형태소 분석 시작558
# 형태소 분석 시작559
# 형태소 분석 시작560
# 형태소 분석 시작561
# 형태소 분석 시작562
# 형태소 분석 시작563
# 형태소 분석 시작564
# 형태소 분석 시작565
# 형태소 분석 시작566
# 형태소 분석 시작567
# 형태소 분석 시작568
# 형태소 분석 시작569
# 형태소 분석 시작570
# 형태소 분석 시작571
# 형태소 분석 시작572
# 형태소 분석 시작573
# 형태소 분석 시작574
# 형태소 분석 시작575
# 형태소 분석 시작576
# 형태소 분석 시작577
# 형태소 분석 시작578
# 형태소 분석 시작579
# 형태소 분석 시작580
# 형태소 분석 시작581
# 형태소 분석 시작582
# 형태소 분석 시작583
# 형태소 분석 시작584
# 형태소 분석 시작585
# 형태소 분석 시작586
# 형태소 분석 시작587
# 형태소 분석 시작588
# 형태소 분석 시작589
# 형태소 분석 시작590
# 형태소 분석 시작591
# 형태소 분석 시작592
# 형태소 분석 시작593
# 형태소 분석 시작594
# 형태소 분석 시작595
# 형태소 분석 시작596
# 형태소 분석 시작597
# 형태소 분석 시작598
# 형태소 분석 시작599
# 형태소 분석 시작600
# 형태소 분석 시작601
# 형태소 분석 시작602
# 형태소 분석 시작603
# 형태소 분석 시작604
# 형태소 분석 시작605
# 형태소 분석 시작606
# 형태소 분석 시작607
# 형태소 분석 시작608
# 형태소 분석 시작609
# 형태소 분석 시작610
# 형태소 분석 시작611
# 형태소 분석 시작612
# 형태소 분석 시작613
# 형태소 분석 시작614
# 형태소 분석 시작615
# 형태소 분석 시작616
# 형태소 분석 시작617
# 형태소 분석 시작618
# 형태소 분석 시작619
# 형태소 분석 시작620
# 형태소 분석 시작621
# 형태소 분석 시작622
# 형태소 분석 시작623
# 형태소 분석 시작624
# 형태소 분석 시작625
# 형태소 분석 시작626
# 형태소 분석 시작627
# 형태소 분석 시작628

# %%
stop_words_work = ["일자리", '청원','정부','한국','문재','대통령님', "정규직"]
stop_words_work.extend(one_words2)
len(stop_words_work)

work_nouns2 = [word for word in nounswork if word not in stop_words_work]
len(work_nouns)

work_nouns2 = nltk.Text(work_nouns2, name = "일자리")
work_noun_common2 = work_nouns2.vocab().most_common()

# %%
plt.figure(figsize=(10,4))
work_nouns2.plot(30)
plt.show()

# %%
work_nouns2.collocations(window_size=3)
# Out:
# 거짓말 최저임금에관한의견; 장애인최저임금 적용제외; 국민제안 청원시리즈; 서울시교육청 민간기업; 안지켜주 민간기업; 안지켜주
# 서울시교육청; 일자리대책 최저임금대책; 저출산대책 일자리대책; 청원시리즈 저출산대책; 최저시급 시간제알바에; 최저임금대책
# 정규직대책; 민간기업 공공기업; 서울시교육청 공공기업; 정규직대책 시급한; 최저임금적용 50대주부비정규직짤림; (평창
# 비자정책; /제조업최악 신기록; /제조업최악 이미지; 10달러 단순비교시; 13년 자영업의길

# %%
ww2 = dict(work_noun_common2)
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(ww2)
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
